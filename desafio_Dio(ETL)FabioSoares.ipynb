# %% [markdown]
# <a href="https://colab.research.google.com/github/Soares-remootFR/desafio_ETL_Dio/blob/main/desafio_Dio(ETL)FabioSoares.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fazendo uploade e tratamento da base de dados pública Titanic.

# %%
# bibliotecas utilizadas
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# leitura do data set
df = pd.read_csv('https://raw.githubusercontent.com/adamerose/datasets/master/titanic.csv')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# identificação dos valores duplicados
df[df.duplicated(keep=False)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# 26          0       3    male   NaN      0      0   7.2250        C   Third
# 28          1       3  female   NaN      0      0   7.8792        Q   Third
# 29          0       3    male   NaN      0      0   7.8958        S   Third
# 32          1       3  female   NaN      0      0   7.7500        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 870         0       3    male  26.0      0      0   7.8958        S   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# valores duplicados por cada duplicata
(
  df
 .groupby(df.columns.tolist(), dropna=False)
 .size()
 .to_frame('n_duplicates')
 .query('n_duplicates>1')
 .sort_values('n_duplicates', ascending=False)
 .head(5)
)
# Out:
#                                                                                                              n_duplicates
# survived pclass sex    age sibsp parch fare   embarked class  who   adult_male deck embark_town alive alone
# 0        3      male   NaN 0     0     7.8958 S        Third  man   True       NaN  Southampton no    True             13
#                                        8.0500 S        Third  man   True       NaN  Southampton no    True             12
#                                        7.7500 Q        Third  man   True       NaN  Queenstown  no    True              8
# 1        3      female NaN 0     0     7.7500 Q        Third  woman False      NaN  Queenstown  yes   True              7
# 0        2      male   NaN 0     0     0.0000 S        Second man   True       NaN  Southampton no    True              6

# %%
# Removendo valores duplicados
df.drop_duplicates()
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           0       3    male  22.0      1      0   7.2500        S  Third
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 2           1       3  female  26.0      0      0   7.9250        S  Third
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 4           0       3    male  35.0      0      0   8.0500        S  Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 885         0       3  female  39.0      0      5  29.1250        Q  Third
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 888         0       3  female   NaN      1      2  23.4500        S  Third
# 889         1       1    male  26.0      0      0  30.0000        C  First
# 890         0       3    male  32.0      0      0   7.7500        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Identificar e mostrar valores nulos
df_missing = (
  df.isna().sum()
  .to_frame('missing_count')
  .join((df.isna().sum() / df.shape[0]).to_frame('missing_pct'))
  .sort_values('missing_count', ascending=False)
)

df_missing.style.format('{:.2%}', subset=['missing_pct'])
# Out:
# <style type="text/css">
# </style>
# <table id="T_cf9df" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf9df_level0_col0" class="col_heading level0 col0" >missing_count</th>
#       <th id="T_cf9df_level0_col1" class="col_heading level0 col1" >missing_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf9df_level0_row0" class="row_heading level0 row0" >deck</th>
#       <td id="T_cf9df_row0_col0" class="data row0 col0" >688</td>
#       <td id="T_cf9df_row0_col1" class="data row0 col1" >77.22%</td>
#     </tr>
#     <tr>
#       <th id="T_cf9df_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_cf9df_row1_col0" class="data row1 col0" >177</td>
#       <td id="T_cf9df_row1_col1" class="data row1 col1" >19.87%</td>
#     </tr>
#     <tr>
#       <th id="T_cf9df_level0_row2" class="row_heading level0 row2" >embarked</th>
# ...

# %%
# Removendo coluna deck
df.drop(columns=['deck'])
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
# imputando média a valores nulos na coluna "age"
# imputando a moda aos valores nulos na coluna "embarked"

df.fillna({'age': df.age.mean(), 'embarked': df.embarked.mode()[0]}).tail()
# Out:
#      survived  pclass     sex        age  sibsp  parch   fare embarked  \
# 886         0       2    male  27.000000      0      0  13.00        S
# 887         1       1  female  19.000000      0      0  30.00        S
# 888         0       3  female  29.699118      1      2  23.45        S
# 889         1       1    male  26.000000      0      0  30.00        C
# 890         0       3    male  32.000000      0      0   7.75        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# 886  Second    man        True  NaN  Southampton    no   True
# 887   First  woman       False    B  Southampton   yes   True
# 888   Third  woman       False  NaN  Southampton    no  False
# 889   First    man        True    C    Cherbourg   yes   True
# 890   Third    man        True  NaN   Queenstown    no   True

# %%
# dataset tratado
df.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...
